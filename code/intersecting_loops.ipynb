# %%
#import sys
#sys.path = ["/usr/local/lib/python3.9/site-packages"] + sys.path

import spot, buddy
import random
from IPython.display import display
import WBA_utils
import intersecting_loops
from copy import deepcopy as deepcopy
import time

# %%
wup = 3
s0 = 0
c0 = 2
mode = 2

for n in range(2,6):
    WBA_utils.BuechiEnergy(intersecting_loops.bench(n, wup), s0, wup, c0, mode)
# Out:
# Original automaton
# Prefix energy per state
# array('q', [3, 3])
# Current optimal predescessor
# [[2], [1]]
# State names are: "state number, max energy"
# Optimal predescessor is highlighted in pink
# Checking SCC 0
# Degeneralized SCC has: 2 states, 2 edges and 1 back-edges.
# Current SCC with: 2 states and 1 back-edges
# {0: 0, 1: 1}
# Analysing backedge 1:0 -> 0:0.
# We start with 3 energy in state 0:0.
# array('q', [3, 3]) [[], [1]]
# We found a non-negative loop using edge 1:0 -> 0:0 directly.
# Original automaton
# Prefix energy per state
# array('q', [3, 3, 3, 3, 3, 3])
# Current optimal predescessor
# [[9], [1, 3], [4, 6], [2], [5], [8]]
# State names are: "state number, max energy"
# Optimal predescessor is highlighted in pink
# Checking SCC 0
# Degeneralized SCC has: 6 states, 9 edges and 1 back-edges.
# Current SCC with: 6 states and 1 back-edges
# {0: 0, 1: 1, 3: 2, 2: 3, 4: 4, 5: 5}
# Analysing backedge 2:0 -> 0:0.
# We start with 3 energy in state 0:0.
# array('q', [3, 3, 3, 3, 3, 3]) [[], [1, 5], [3], [4, 8], [6], [2]]
# We restart with 0 energy in state 0:0.
# array('q', [3, 3, 3, 3, 3, 3]) [[9], [1, 5], [3], [4, 8], [6], [2]]
# We found a non-negative loop using edge 2:0 -> 0:0 in the second iteration.
# Original automaton
# Prefix energy per state
# array('q', [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])
# Current optimal predescessor
# [[32], [1, 8], [9, 16], [17, 24], [2, 4], [3], [5, 7], [6], [10, 12], [11], [13, 15], [14], [18, 20], [19], [21, 23], [22], [26, 28], [27], [29, 31], [30]]
# State names are: "state number, max energy"
# Optimal predescessor is highlighted in pink
# Checking SCC 0
# Degeneralized SCC has: 20 states, 32 edges and 1 back-edges.
# Current SCC with: 20 states and 1 back-edges
# {0: 0, 1: 1, 4: 2, 5: 3, 6: 4, 7: 5, 2: 6, 8: 7, 9: 8, 10: 9, 11: 10, 3: 11, 12: 12, 13: 13, 14: 14, 15: 15, 16: 16, 17: 17, 18: 18, 19: 19}
# Analysing backedge 3:0 -> 0:0.
# We start with 3 energy in state 0:0.
# array('q', [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]) [[], [1, 9], [3, 7], [5], [6, 10], [8], [4, 17], [11, 15], [13], [14, 18], [16], [12, 25], [19, 23], [21], [22, 26], [24], [2], [27], [28, 32], [30]]
# We restart with 0 energy in state 0:0.
# array('q', [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]) [[31], [1, 9], [3, 7], [5], [6, 10], [8], [4, 17], [11, 15], [13], [14, 18], [16], [12, 25], [19, 23], [21], [22, 26], [24], [2, 29], [27], [28, 32], [30]]
# We found a non-negative loop using edge 3:0 -> 0:0 in the second iteration.
# Original automaton
# Prefix energy per state
# array('q', [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])
# Current optimal predescessor
