# %%
import spot, buddy, copy
import WBA_utils as wu
import WBA_solvers as ws

# %% [markdown]
# ## Büchi automata

# %%
wu.OmegaEnergy("../tests/small_buechi_2.hoa", 0, 1000, 0, 2)
# Out:
# (Generalized) Büchi condition detected.
# Original automaton
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Pages: 1 -->
# <svg width="349pt" height="147pt"
#  viewBox="0.00 0.00 349.00 147.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 143)">
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-143 345,-143 345,4 -4,4"/>
# <text text-anchor="start" x="147.5" y="-124.8" font-family="Times,serif" font-size="14.00">Inf(</text>
# <text text-anchor="start" x="172.5" y="-124.8" font-family="Times,serif" font-size="14.00" fill="#1f78b4">⓿</text>
# <text text-anchor="start" x="187.5" y="-124.8" font-family="Times,serif" font-size="14.00">)</text>
# ...

# %%
wu.OmegaEnergy("../tests/medium_buechi.hoa", 0, 75, 0, 1)
# Out:
# (Generalized) Büchi condition detected.
# Original automaton
# Prefix energy per state
# 0:0
# 1:75
# 2:75
# 3:75
# 4:75
# 5:75
#
# Current optimal predecessor
# 0: None
# 1: [(0,0), (2,0), (4,-25), (2,0)]
# 2: [(1,0), (3,-50), (1,0), (5,0)]
# 3: [(2,0), (3,1), (3,1)]
# 4: [(1,-25), (4,1), (4,1)]
# 5: [(2,-50), (5,1), (5,1)]
#
# State names are: "state number, max energy"
# Optimal predecessor is highlighted in pink
# Checking SCC 0
# Degeneralized SCC has: 6 states, 13 edges and 1 back-edges.
# Current SCC with: 6 states and 1 back-edges
# Associating states in the original automaton to the corresponding states in lvl 0 of the degeneralised SCC
# {0: 0, 1: 1, 2: 2, 3: 3, 5: 4, 4: 5}
# Analysing backedge 1:0 -> 0:0.
# We start with 0 energy in state 0:0.
# Energy starting in backedge dst
# 0:0
# 1:75
# 2:75
# 3:75
# 4:75
# 5:75
# Corresponding predecessors
# 0: None
# 1: [(0,0), (2,0), (5,-25), (2,0)]
# 2: [(1,0), (3,-50), (1,0), (4,0)]
# 3: [(2,0), (3,1), (3,1)]
# ...

# %%
wu.OmegaEnergy("../tests/medium_buechi.hoa", 0, 5, 0, 1)
# Out:
# (Generalized) Büchi condition detected.
# Original automaton
# Prefix energy per state
# 0:0
# 1:0
# 2:0
# 3:5
# 4:-1
# 5:-1
#
# Current optimal predecessor
# 0: None
# 1: [(0,0)]
# 2: [(1,0)]
# 3: [(2,0), (3,1), (3,1)]
# 4: None
# 5: None
#
# State names are: "state number, max energy"
# Optimal predecessor is highlighted in pink
# Checking SCC 0
# Degeneralized SCC has: 6 states, 13 edges and 1 back-edges.
# Current SCC with: 6 states and 1 back-edges
# Associating states in the original automaton to the corresponding states in lvl 0 of the degeneralised SCC
# {0: 0, 1: 1, 2: 2, 3: 3, 5: 4, 4: 5}
# Analysing backedge 1:0 -> 0:0.
# We start with 0 energy in state 0:0.
# Energy starting in backedge dst
# 0:0
# 1:0
# 2:0
# 3:5
# 4:-1
# 5:-1
# Corresponding predecessors
# 0: None
# 1: [(0,0)]
# 2: [(1,0)]
# 3: [(2,0), (3,1), (3,1)]
# 4: None
# 5: None
#
# No feasible Büchi run detected!
# ...

# %% [markdown]
# ## Parity automata
